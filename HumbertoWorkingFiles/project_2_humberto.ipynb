# %%
import pandas as pd

# %% [markdown]
# Check rows and columns for unnamed and naming

# %%
df = pd.read_csv('sfRealEstate.csv', index_col=False)
df.tail()
# df.reset_index().to_json('sfRealEstate.json', orient="records")

# df.drop('Unnamed: 0', axis=1, inplace=True)
# Out:
#                  property_type                        address           city  \
# 345                Condo/Co-op              155 Harriet St #8  San Francisco
# 346                Condo/Co-op                   769 19th Ave  San Francisco
# 347                Condo/Co-op  355 Buena Vista Ave Unit 512W  San Francisco
# 348  Single Family Residential                  2587 41st Ave  San Francisco
# 349                Condo/Co-op          1160 Mission St #1907  San Francisco
#
#     state    zip    price  beds  baths     neighborhoods  square_feet  \
# 345    CA  94103   999000   2.0    2.0   South of Market          NaN
# 346    CA  94121  1425000   2.0    1.5  Central Richmond       1400.0
# 347    CA  94117  1425000   2.0    2.0  Buena Vista Park       1030.0
# 348    CA  94116  1095000   3.0    2.0    Outer Parkside       1655.0
# 349    CA  94103  1200000   2.0    2.0   South of Market       1043.0
#
#      price_per_square_feet  hoa/month        lat         lng  built_year  \
# ...

# %%
# df.to_csv('sfRealEstate.csv', index=False)

# %% [markdown]
# Convert to json

# %%
# df = pd.read_csv('sfRealEstate.csv', index_col=False)
df.to_json('sfRealEstate.json', orient='records')
