# %%
import pandas as pd

# %%
redfin_original_csv = pd.read_csv('/redfin_neighborhood_match_data.csv')
redfin_original_csv.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-33cbf21fd8fa> in <module>
# ----> 1 redfin_original_csv = pd.read_csv('redfin_neighborhood_match_data.csv')
#       2 redfin_original_csv.head()
#
# ...

# %%
# list(redfin_original_csv.columns)

# %%
redfin_columns_removed = redfin_original_csv[['PROPERTY TYPE', 'ADDRESS', 'CITY', 'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS', 'LOCATION', 'SQUARE FEET', 'YEAR BUILT', '$/SQUARE FEET', 'HOA/MONTH', 'LATITUDE', 'LONGITUDE']]
redfin_columns_removed.head()
# Out:
#   PROPERTY TYPE                 ADDRESS           CITY STATE OR PROVINCE  \
# 0   Condo/Co-op           1548 Jones St  San Francisco                CA
# 1   Condo/Co-op     2200 Market St #402  San Francisco                CA
# 2   Condo/Co-op  2040 Franklin St #1004  San Francisco                CA
# 3   Condo/Co-op    1425 Vallejo St #205  San Francisco                CA
# 4   Condo/Co-op        260 King St #903  San Francisco                CA
#
#   ZIP OR POSTAL CODE    PRICE  BEDS  BATHS         LOCATION  SQUARE FEET  \
# 0              94109  1400000   2.0    2.0         Nob Hill       1158.0
# 1              94114  1150000   1.0    1.5  Duboce Triangle        825.0
# 2              94109   998000   1.0    1.0  Pacific Heights        919.0
# 3              94109  1349000   2.0    2.0     Russian Hill       1034.0
# 4              94107  1249000   2.0    2.0      Mission Bay       1286.0
#
#    YEAR BUILT  $/SQUARE FEET  HOA/MONTH   LATITUDE   LONGITUDE
# ...

# %%
redfin_columns_removed["COORDINATES"] = redfin_columns_removed["LATITUDE"].astype(str) +"," + redfin_columns_removed["LONGITUDE"].astype(str)
redfin_columns_removed.head()
# Out:
# /Users/cynthiakellogg/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#   PROPERTY TYPE                 ADDRESS           CITY STATE OR PROVINCE  \
# 0   Condo/Co-op           1548 Jones St  San Francisco                CA
# 1   Condo/Co-op     2200 Market St #402  San Francisco                CA
# 2   Condo/Co-op  2040 Franklin St #1004  San Francisco                CA
# 3   Condo/Co-op    1425 Vallejo St #205  San Francisco                CA
# 4   Condo/Co-op        260 King St #903  San Francisco                CA
#
#   ZIP OR POSTAL CODE    PRICE  BEDS  BATHS         LOCATION  SQUARE FEET  \
# ...

# %%
redfin_location_combined = pd.DataFrame(redfin_columns_removed)

# %%
redfin_location_combined
# Out:
#                  PROPERTY TYPE                        ADDRESS           CITY  \
# 0                  Condo/Co-op                  1548 Jones St  San Francisco
# 1                  Condo/Co-op            2200 Market St #402  San Francisco
# 2                  Condo/Co-op         2040 Franklin St #1004  San Francisco
# 3                  Condo/Co-op           1425 Vallejo St #205  San Francisco
# 4                  Condo/Co-op               260 King St #903  San Francisco
# ..                         ...                            ...            ...
# 345                Condo/Co-op              155 Harriet St #8  San Francisco
# 346                Condo/Co-op                   769 19th Ave  San Francisco
# 347                Condo/Co-op  355 Buena Vista Ave Unit 512W  San Francisco
# 348  Single Family Residential                  2587 41st Ave  San Francisco
# 349                Condo/Co-op          1160 Mission St #1907  San Francisco
#
# ...

# %%
redfin_location_combined['YEAR BUILT'] = redfin_location_combined['YEAR BUILT'].astype(str)

# %%
redfin_location_combined['BUILT YEAR'] = redfin_location_combined['YEAR BUILT'].astype(str).str[:4]
redfin_location_combined
# Out:
#                  PROPERTY TYPE                        ADDRESS           CITY  \
# 0                  Condo/Co-op                  1548 Jones St  San Francisco
# 1                  Condo/Co-op            2200 Market St #402  San Francisco
# 2                  Condo/Co-op         2040 Franklin St #1004  San Francisco
# 3                  Condo/Co-op           1425 Vallejo St #205  San Francisco
# 4                  Condo/Co-op               260 King St #903  San Francisco
# ..                         ...                            ...            ...
# 345                Condo/Co-op              155 Harriet St #8  San Francisco
# 346                Condo/Co-op                   769 19th Ave  San Francisco
# 347                Condo/Co-op  355 Buena Vista Ave Unit 512W  San Francisco
# 348  Single Family Residential                  2587 41st Ave  San Francisco
# 349                Condo/Co-op          1160 Mission St #1907  San Francisco
#
# ...

# %%
redfin_location_combined.head()
# Out:
#   PROPERTY TYPE                 ADDRESS           CITY STATE OR PROVINCE  \
# 0   Condo/Co-op           1548 Jones St  San Francisco                CA
# 1   Condo/Co-op     2200 Market St #402  San Francisco                CA
# 2   Condo/Co-op  2040 Franklin St #1004  San Francisco                CA
# 3   Condo/Co-op    1425 Vallejo St #205  San Francisco                CA
# 4   Condo/Co-op        260 King St #903  San Francisco                CA
#
#   ZIP OR POSTAL CODE    PRICE  BEDS  BATHS         LOCATION  SQUARE FEET  \
# 0              94109  1400000   2.0    2.0         Nob Hill       1158.0
# 1              94114  1150000   1.0    1.5  Duboce Triangle        825.0
# 2              94109   998000   1.0    1.0  Pacific Heights        919.0
# 3              94109  1349000   2.0    2.0     Russian Hill       1034.0
# 4              94107  1249000   2.0    2.0      Mission Bay       1286.0
#
#   YEAR BUILT  $/SQUARE FEET  HOA/MONTH   LATITUDE   LONGITUDE  \
# ...

# %%
redfin_year_new = redfin_location_combined[['PROPERTY TYPE', 'ADDRESS', 'CITY', 'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS', 'LOCATION', 'SQUARE FEET', '$/SQUARE FEET', 'HOA/MONTH', 'LATITUDE', 'LONGITUDE', 'BUILT YEAR', 'COORDINATES']]

# %%
redfin_year_new.head()
# Out:
#   PROPERTY TYPE                 ADDRESS           CITY STATE OR PROVINCE  \
# 0   Condo/Co-op           1548 Jones St  San Francisco                CA
# 1   Condo/Co-op     2200 Market St #402  San Francisco                CA
# 2   Condo/Co-op  2040 Franklin St #1004  San Francisco                CA
# 3   Condo/Co-op    1425 Vallejo St #205  San Francisco                CA
# 4   Condo/Co-op        260 King St #903  San Francisco                CA
#
#   ZIP OR POSTAL CODE    PRICE  BEDS  BATHS         LOCATION  SQUARE FEET  \
# 0              94109  1400000   2.0    2.0         Nob Hill       1158.0
# 1              94114  1150000   1.0    1.5  Duboce Triangle        825.0
# 2              94109   998000   1.0    1.0  Pacific Heights        919.0
# 3              94109  1349000   2.0    2.0     Russian Hill       1034.0
# 4              94107  1249000   2.0    2.0      Mission Bay       1286.0
#
#    $/SQUARE FEET  HOA/MONTH   LATITUDE   LONGITUDE BUILT YEAR  \
# ...

# %%
redfin_year_new.groupby("LOCATION").count()
# Out:
#                        PROPERTY TYPE  ADDRESS  CITY  STATE OR PROVINCE  \
# LOCATION
# 699 - Not Defined                  1        1     1                  1
# Alamo Square                       1        1     1                  1
# Anza Vista                         1        1     1                  1
# Bayview                            5        4     5                  5
# Bernal Heights                     7        7     7                  7
# ...                              ...      ...   ...                ...
# Telegraph Hill                     3        3     3                  3
# Twin Peaks                         3        3     3                  3
# Van Ness/Civic Center              1        1     1                  1
# Westwood Highlands                 2        2     2                  2
# Yerba Buena                        8        8     8                  8
#
#                        ZIP OR POSTAL CODE  PRICE  BEDS  BATHS  SQUARE FEET  \
# LOCATION
# ...

# %%
redfin_year_new.groupby("LOCATION").mean().sort_values("$/SQUARE FEET", ascending=True)
# Out:
#                          PRICE  BEDS  BATHS  SQUARE FEET  $/SQUARE FEET  \
# LOCATION
# Huntington Lake       119000.0  1.00   1.00   608.000000     196.000000
# Mission Terrace      1498888.0  5.00   3.00  2432.000000     616.000000
# Outer Parkside       1095000.0  3.00   2.00  1655.000000     662.000000
# Candlestick Point     728000.0  2.00   2.00  1095.000000     665.000000
# Bayview               940800.0  3.20   1.90  1492.500000     683.750000
# ...                        ...   ...    ...          ...            ...
# Russian Hill         2824200.0  2.00   2.20  1963.333333    1457.000000
# Pacific Heights      5792750.0  2.25   2.75  2695.428571    1661.714286
# Alamo Square         4998000.0  7.00   5.00          NaN            NaN
# Golden Gate Heights  1325000.0  2.00   1.00          NaN            NaN
# Ingleside             813500.0  1.50   1.00          NaN            NaN
#
#                      HOA/MONTH   LATITUDE   LONGITUDE
# LOCATION
# ...

# %%
new_df = redfin_year_new.groupby("LOCATION").mean().sort_values("$/SQUARE FEET", ascending=False)
new_df
# Out:
#                             PRICE      BEDS     BATHS  SQUARE FEET  \
# LOCATION
# Pacific Heights      5.792750e+06  2.250000  2.750000  2695.428571
# Russian Hill         2.824200e+06  2.000000  2.200000  1963.333333
# Marina               3.627857e+06  2.571429  2.428571  2241.571429
# Presidio Heights     5.387500e+06  4.500000  3.500000  3589.000000
# Telegraph Hill       2.481667e+06  3.000000  2.166667   758.000000
# ...                           ...       ...       ...          ...
# Mission Terrace      1.498888e+06  5.000000  3.000000  2432.000000
# Huntington Lake      1.190000e+05  1.000000  1.000000   608.000000
# Alamo Square         4.998000e+06  7.000000  5.000000          NaN
# Golden Gate Heights  1.325000e+06  2.000000  1.000000          NaN
# Ingleside            8.135000e+05  1.500000  1.000000          NaN
#
#                      $/SQUARE FEET  HOA/MONTH   LATITUDE   LONGITUDE
# LOCATION
# Pacific Heights        1661.714286      872.0  37.794111 -122.430178
# ...

# %%
# find real estate for Lakeshore, Mission, Tenderloin
# df.loc[(df['Color'] == 'Green')

pac_heights_df = redfin_year_new.loc[(redfin_year_new['LOCATION'] == 'Pacific Heights')]

pac_heights_df
# Out:
#                  PROPERTY TYPE                   ADDRESS           CITY  \
# 2                  Condo/Co-op    2040 Franklin St #1004  San Francisco
# 84                 Condo/Co-op     1895 Pacific Ave #104  San Francisco
# 107                Condo/Co-op        2100 Green St #704  San Francisco
# 163                Condo/Co-op      1755 Jackson St #406  San Francisco
# 172                Condo/Co-op  2200 Sacramento St #1305  San Francisco
# 242                Condo/Co-op      1870 Jackson St #301  San Francisco
# 306  Single Family Residential           2341 Vallejo St  San Francisco
# 324  Single Family Residential             2590 Green St  San Francisco
#
#     STATE OR PROVINCE ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  \
# 2                  CA              94109    998000   1.0    1.0
# 84                 CA              94109    599000   0.0    1.0
# 107                CA              94123   3495000   2.0    2.0
# ...

# %%
redfin_year_new.to_csv('../Resources/clean_redfin_data.csv', index = True)

# %%
pac_heights_df.describe()
# Out:
#               PRICE      BEDS    BATHS  SQUARE FEET  $/SQUARE FEET  \
# count  8.000000e+00  8.000000  8.00000     7.000000       7.000000
# mean   5.792750e+06  2.250000  2.75000  2695.428571    1661.714286
# std    9.477791e+06  1.669046  2.37547  2806.028502     802.113191
# min    5.990000e+05  0.000000  1.00000   512.000000    1086.000000
# 25%    1.487000e+06  1.000000  1.00000  1134.500000    1175.000000
# 50%    2.150000e+06  2.000000  2.00000  1866.000000    1222.000000
# 75%    4.246250e+06  3.250000  3.25000  2795.500000    1818.500000
# max    2.880000e+07  5.000000  8.00000  8630.000000    3337.000000
#
#         HOA/MONTH   LATITUDE   LONGITUDE
# count     6.00000   8.000000    8.000000
# mean    872.00000  37.794111 -122.430178
# std     401.05062   0.001753    0.006397
# min     440.00000  37.790681 -122.441718
# 25%     699.00000  37.793533 -122.434438
# 50%     775.00000  37.794014 -122.427871
# 75%     906.50000  37.795105 -122.425470
# ...

# %%
mission_df = redfin_year_new.loc[(redfin_year_new['LOCATION'] == 'Inner Mission')]

mission_df
# Out:
#                  PROPERTY TYPE                ADDRESS           CITY  \
# 10                 Condo/Co-op       2987 Harrison St  San Francisco
# 21                 Condo/Co-op   1875 Mission St #108  San Francisco
# 64                 Condo/Co-op         1298 Treat Ave  San Francisco
# 211                Condo/Co-op  1188 Valencia St #210  San Francisco
# 226                Condo/Co-op       3418 26th St #11  San Francisco
# 265    Multi-Family (2-4 Unit)      3132-3136 23rd St  San Francisco
# 273                Condo/Co-op    45 Bartlett St #416  San Francisco
# 281                Condo/Co-op        2600 18th St #7  San Francisco
# 294  Single Family Residential           2851 25th St  San Francisco
# 308                Condo/Co-op            755 Capp St  San Francisco
#
#     STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS       LOCATION  \
# 10                 CA              94110  1325000   3.0    2.0  Inner Mission
# ...

# %%
mission_df.describe()
# Out:
#               PRICE       BEDS     BATHS  SQUARE FEET  $/SQUARE FEET  \
# count  1.000000e+01  10.000000  10.00000     8.000000       8.000000
# mean   1.161800e+06   2.200000   1.55000  1411.125000     957.000000
# std    4.249146e+05   1.398412   0.68516   605.253297     228.568214
# min    6.490000e+05   0.000000   1.00000   517.000000     548.000000
# 25%    7.615000e+05   1.000000   1.00000  1092.250000     872.500000
# 50%    1.224500e+06   2.500000   1.25000  1481.000000     997.500000
# 75%    1.318500e+06   3.000000   2.00000  1867.500000    1026.250000
# max    1.895000e+06   4.000000   3.00000  2191.000000    1350.000000
#
#        HOA/MONTH   LATITUDE   LONGITUDE
# count    8.00000  10.000000   10.000000
# mean   429.12500  37.754708 -122.415080
# std    162.38177   0.005840    0.004899
# min    180.00000  37.749202 -122.421016
# 25%    320.00000  37.750128 -122.419210
# 50%    505.00000  37.754051 -122.416142
# 75%    547.50000  37.755521 -122.411660
# ...

# %%
tenderloin_df = redfin_year_new.loc[(redfin_year_new['LOCATION'] == 'Tenderloin')]

tenderloin_df
# Out:
# Empty DataFrame
# Columns: [PROPERTY TYPE, ADDRESS, CITY, STATE OR PROVINCE, ZIP OR POSTAL CODE, PRICE, BEDS, BATHS, LOCATION, SQUARE FEET, $/SQUARE FEET, HOA/MONTH, LATITUDE, LONGITUDE, BUILT YEAR, COORDINATES]
# Index: []

# %%
lakeshore_df = redfin_year_new.loc[(redfin_year_new['LOCATION'] == 'Lake')]

lakeshore_df
# Out:
#                  PROPERTY TYPE          ADDRESS           CITY  \
# 66                 Condo/Co-op     1625 Lake St  San Francisco
# 130                Condo/Co-op      750 Lake St  San Francisco
# 230                Condo/Co-op      756 Lake St  San Francisco
# 250  Single Family Residential     135 15th Ave  San Francisco
# 296                Condo/Co-op  225 26th Ave #1  San Francisco
#
#     STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS LOCATION  \
# 66                 CA              94121  1549000   2.0    2.0     Lake
# 130                CA              94118  1895000   2.0    2.0     Lake
# 230                CA              94118  1750000   2.0    2.0     Lake
# 250                CA              94118  4590000   5.0    3.5     Lake
# 296                CA              94121  1959000   4.0    3.5     Lake
#
#      SQUARE FEET  $/SQUARE FEET  HOA/MONTH   LATITUDE   LONGITUDE BUILT YEAR  \
# ...
